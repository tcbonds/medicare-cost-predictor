# %%
import pickle
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_palette("Oranges")

# Modeling Imports
import statsmodels.api as sm
import statsmodels.formula.api as smf
import patsy

from sklearn.linear_model import LinearRegression, Ridge, Lasso, RidgeCV, LassoCV, ElasticNet
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# Unpickling cleaned dataframe from 1_Data_Cleaning.ipynb

redo_pickle = False

if redo_pickle == True:
    with open('clean_df.pickle','rb') as f:
        clean_df = pickle.load(f)

# %% [markdown]
# ## Visualizations Before Modeling

# %%
# Creating heatmap to look for multicolinearity and correlations 
# between target(TOTAL_MEDICARE_PAYMENT_AMT) and all predictor variables

plt.figure(figsize=(10,10))
sns.heatmap(clean_df.corr(), cmap='Oranges');

# %%
# Before and After Logarithmic transformation of target variable(Medicare Cost per Provider)
sns.set_style("ticks")

plt.figure(figsize=(20,10))
plt.subplot(121)
sns.distplot(clean_df.TOTAL_MEDICARE_PAYMENT_AMT, bins=100, color='darkorange')

plt.xlabel('Medicare Cost', fontsize=20)
plt.ylabel('Frequency', fontsize=20)

plt.subplot(122)
sns.distplot(np.log(clean_df.TOTAL_MEDICARE_PAYMENT_AMT), bins=100, color='darkorange')
plt.xlabel('Logarithm of Medicare Cost', fontsize=20);

# %%
# Before and After Logarithmic transformation of predictor variable (Total Services)
plt.figure(figsize=(20,10))
plt.subplot(121)
sns.distplot(clean_df.TOTAL_SERVICES, bins=100, color='darkorange')

plt.xlabel('Services', fontsize=20)
plt.ylabel('Frequency', fontsize=20)

plt.subplot(122)
sns.distplot(np.log(clean_df.TOTAL_SERVICES), bins=100, color='darkorange')
plt.xlabel('Logarithm of Services', fontsize=20);

# %%
# Before and After Logarithmic transformation of predictor variable (Number of Unique Medical Services)
plt.figure(figsize=(20,10))
plt.subplot(121)
sns.distplot(clean_df.NUMBER_OF_HCPCS, bins=100, color='darkorange')

plt.xlabel('Services', fontsize=20)
plt.ylabel('Frequency', fontsize=20)

plt.subplot(122)
sns.distplot(np.log(clean_df.NUMBER_OF_HCPCS), bins=100, color='darkorange')
plt.xlabel('Logarithm of Services', fontsize=20);

# %%
# Before and after log transformation of the above target and predictor variable

# This demonstrates that the log-log transformation leads to a greater linearity
plt.figure(figsize=(20,10), dpi=200)

plt.subplot(121)
plt.scatter(x=clean_df.TOTAL_SERVICES, y=clean_df.TOTAL_MEDICARE_PAYMENT_AMT, alpha=1)
plt.xlabel('Services per Doctor', fontsize=20)
plt.ylabel('Medicare Cost', fontsize=20)

plt.subplot(122)
plt.scatter(np.log(clean_df.TOTAL_SERVICES),np.log(clean_df.TOTAL_MEDICARE_PAYMENT_AMT), alpha=1)
plt.xlabel('Logarithm of Services per Doctor', fontsize=20)
plt.ylabel('Logarithm of Medicare Cost', fontsize=20);

# %% [markdown]
# ## Initial Model Testing without Feature Engineering

# %%
def ols_formula(df, dependent_var, *excluded_cols):
    '''
    Returns the "R style" formula for the patsy function given
    the dataframe, target variable and optional excluded columns
    as strings
    '''
    df_columns = list(df.columns.values)
    df_columns.remove(dependent_var)
    for col in excluded_cols:
        df_columns.remove(col)
    return dependent_var + ' ~ ' + ' + '.join(df_columns)

# %%
## Initial Statsmodel OLS 
# (Variable naming clarification: no_fe means no feature engineering)

formula = ols_formula(clean_df, 'TOTAL_MEDICARE_PAYMENT_AMT')
y, X = patsy.dmatrices(formula, data=clean_df, return_type="dataframe")
model_no_fe = sm.OLS(y, X)
fit_no_fe = model_no_fe.fit()
fit_no_fe.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     TOTAL_MEDICARE_PAYMENT_AMT   R-squared:                       0.619
# Model:                                    OLS   Adj. R-squared:                  0.619
# Method:                         Least Squares   F-statistic:                     9398.
# Date:                        Tue, 16 Jul 2019   Prob (F-statistic):               0.00
# Time:                                13:46:00   Log-Likelihood:            -1.2963e+07
# No. Observations:                      984927   AIC:                         2.593e+07
# Df Residuals:                          984756   BIC:                         2.593e+07
# Df Model:                                 170
# Covariance Type:                    nonrobust
# ===================================================================================================================================
#                                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                        4.078e+04   1.03e+04      3.958      0.000    2.06e+04     6.1e+04
# NPPES_PROVIDER_GENDER[T.M]                                       1.058e+04    296.905     35.644      0.000       1e+04    1.12e+04
# NPPES_PROVIDER_STATE[T.AL]                                      -4870.7260   2785.968     -1.748      0.080   -1.03e+04     589.677
# NPPES_PROVIDER_STATE[T.AR]                                      -7227.0066   2923.865     -2.472      0.013    -1.3e+04   -1496.330
# NPPES_PROVIDER_STATE[T.AZ]                                       3095.6087   2714.038      1.141      0.254   -2223.814    8415.031
# NPPES_PROVIDER_STATE[T.CA]                                      -1085.5877   2597.608     -0.418      0.676   -6176.811    4005.636
# NPPES_PROVIDER_STATE[T.CO]                                      -9367.1961   2736.862     -3.423      0.001   -1.47e+04   -4003.039
# NPPES_PROVIDER_STATE[T.CT]                                      -1.121e+04   2763.190     -4.057      0.000   -1.66e+04   -5794.032
# NPPES_PROVIDER_STATE[T.DC]                                      -1.353e+04   3367.363     -4.018      0.000   -2.01e+04   -6929.514
# NPPES_PROVIDER_STATE[T.DE]                                       7729.8874   3315.321      2.332      0.020    1231.970    1.42e+04
# NPPES_PROVIDER_STATE[T.FL]                                       3917.3110   2620.026      1.495      0.135   -1217.852    9052.474
# NPPES_PROVIDER_STATE[T.GA]                                      -7176.9215   2678.571     -2.679      0.007   -1.24e+04   -1927.013
# NPPES_PROVIDER_STATE[T.HI]                                      -2.319e+04   3389.511     -6.842      0.000   -2.98e+04   -1.65e+04
# NPPES_PROVIDER_STATE[T.IA]                                      -1.185e+04   2839.747     -4.175      0.000   -1.74e+04   -6288.784
# NPPES_PROVIDER_STATE[T.ID]                                      -1.776e+04   3119.225     -5.692      0.000   -2.39e+04   -1.16e+04
# NPPES_PROVIDER_STATE[T.IL]                                      -8318.0051   2633.468     -3.159      0.002   -1.35e+04   -3156.497
# NPPES_PROVIDER_STATE[T.IN]                                      -9421.2557   2710.940     -3.475      0.001   -1.47e+04   -4107.905
# NPPES_PROVIDER_STATE[T.KS]                                      -9843.1372   2850.945     -3.453      0.001   -1.54e+04   -4255.382
# NPPES_PROVIDER_STATE[T.KY]                                      -7584.0741   2767.559     -2.740      0.006    -1.3e+04   -2159.751
# NPPES_PROVIDER_STATE[T.LA]                                      -9980.4309   2779.283     -3.591      0.000   -1.54e+04   -4533.130
# NPPES_PROVIDER_STATE[T.MA]                                      -1.046e+04   2657.232     -3.937      0.000   -1.57e+04   -5253.806
# NPPES_PROVIDER_STATE[T.MD]                                       2742.8062   2708.662      1.013      0.311   -2566.080    8051.693
# NPPES_PROVIDER_STATE[T.ME]                                      -9063.1141   3021.004     -3.000      0.003    -1.5e+04   -3142.047
# NPPES_PROVIDER_STATE[T.MI]                                      -8807.7377   2642.684     -3.333      0.001    -1.4e+04   -3628.166
# NPPES_PROVIDER_STATE[T.MN]                                      -1.789e+04   2690.377     -6.650      0.000   -2.32e+04   -1.26e+04
# NPPES_PROVIDER_STATE[T.MO]                                      -9189.6483   2712.951     -3.387      0.001   -1.45e+04   -3872.356
# NPPES_PROVIDER_STATE[T.MS]                                      -4835.8918   2935.280     -1.648      0.099   -1.06e+04     917.158
# NPPES_PROVIDER_STATE[T.MT]                                      -1.136e+04   3268.648     -3.477      0.001   -1.78e+04   -4957.524
# NPPES_PROVIDER_STATE[T.NC]                                      -7866.0756   2651.979     -2.966      0.003   -1.31e+04   -2668.285
# NPPES_PROVIDER_STATE[T.ND]                                       -1.84e+04   3375.984     -5.450      0.000    -2.5e+04   -1.18e+04
# NPPES_PROVIDER_STATE[T.NE]                                      -1.466e+04   2967.435     -4.939      0.000   -2.05e+04   -8841.374
# NPPES_PROVIDER_STATE[T.NH]                                      -1.008e+04   3042.383     -3.313      0.001    -1.6e+04   -4115.337
# NPPES_PROVIDER_STATE[T.NJ]                                       4860.2097   2670.248      1.820      0.069    -373.387    1.01e+04
# NPPES_PROVIDER_STATE[T.NM]                                      -1.402e+04   3035.200     -4.619      0.000      -2e+04   -8071.152
# NPPES_PROVIDER_STATE[T.NV]                                       7401.0945   2999.102      2.468      0.014    1522.956    1.33e+04
# NPPES_PROVIDER_STATE[T.NY]                                      -6227.4281   2608.205     -2.388      0.017   -1.13e+04   -1115.434
# NPPES_PROVIDER_STATE[T.OH]                                      -1.372e+04   2638.258     -5.201      0.000   -1.89e+04   -8550.759
# NPPES_PROVIDER_STATE[T.OK]                                      -6413.5708   2829.127     -2.267      0.023    -1.2e+04    -868.576
# NPPES_PROVIDER_STATE[T.OR]                                      -1.469e+04   2788.165     -5.269      0.000   -2.02e+04   -9227.274
# NPPES_PROVIDER_STATE[T.PA]                                      -9827.8122   2623.645     -3.746      0.000    -1.5e+04   -4685.555
# NPPES_PROVIDER_STATE[T.RI]                                      -1.144e+04   3183.600     -3.592      0.000   -1.77e+04   -5195.849
# NPPES_PROVIDER_STATE[T.SC]                                      -6879.5038   2773.747     -2.480      0.013   -1.23e+04   -1443.054
# NPPES_PROVIDER_STATE[T.SD]                                      -1.637e+04   3308.265     -4.947      0.000   -2.29e+04   -9883.422
# NPPES_PROVIDER_STATE[T.TN]                                      -9502.3133   2692.820     -3.529      0.000   -1.48e+04   -4224.476
# NPPES_PROVIDER_STATE[T.TX]                                      -7637.5415   2613.560     -2.922      0.003   -1.28e+04   -2515.052
# NPPES_PROVIDER_STATE[T.UT]                                      -1.853e+04   2955.644     -6.270      0.000   -2.43e+04   -1.27e+04
# NPPES_PROVIDER_STATE[T.VA]                                      -5940.6028   2687.416     -2.211      0.027   -1.12e+04    -673.357
+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
def residual_normality_visualizations(pred, res):
    '''Returns visualizations(Q-Q Plot and scatter plot of predictions vs. residuals) 
    checking residuals for normality, using a linear regression model's predictions 
    and its residuals as input.
    '''
    plt.figure(figsize=(8,15))
   
    # Q-Q Plot
    plt.subplot(211)
    stats.probplot(res,dist='norm',plot=plt)
    plt.title('Normal Q-Q plot')
    
    # Predictions vs Residuals Scatter plot
    plt.subplot(212)
    plt.scatter(pred,res)
    plt.title('Predicted vs Residuals Plot')
    plt.xlabel('Predicted Values')
    plt.ylabel('Residuals (Model Errors)')
    
    plt.show();

# %%
residual_normality_visualizations(fit_no_fe.predict(),fit_no_fe.resid)

# Q-Q Plot: Residuals do not fit a normal distribution on the tails
# Predicted vs Residuals: Residuals have a clear boundary and do not follow a normal distribution

# %%
### Running OLS and Ridge Regression in sklearn

# Removing 20% of the data for final testing
X, X_test, y, y_test = train_test_split(X, y, test_size=.4, random_state=10)

# Splitting into val and train sets
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=.25, random_state=11)

# Scaling features for Ridge Regression
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train.values)
X_val_scaled = scaler.transform(X_val.values)
X_test_scaled = scaler.transform(X_test.values)

#Setting up OLS and Ridge Regression
lm = LinearRegression()
lm_reg = Ridge(alpha=1)

# Training and testing
lm.fit(X_train, y_train)
print(f'Linear Regression val R^2: {lm.score(X_val, y_val):.3f}')

lm_reg.fit(X_train_scaled, y_train)
print(f'Ridge Regression val R^2: {lm_reg.score(X_val_scaled, y_val):.3f}')
# Out:
# Linear Regression val R^2: 0.581
# Ridge Regression val R^2: 0.581

# %% [markdown]
# ## Model Testing after Feature Engineering

# %%
clean_df['TOTAL_MEDICARE_PAYMENT_AMT'] = np.log(clean_df.TOTAL_MEDICARE_PAYMENT_AMT)
clean_df['TOTAL_UNIQUE_BENES'] = np.log(clean_df.TOTAL_UNIQUE_BENES)
clean_df['TOTAL_SERVICES'] = np.log(clean_df.TOTAL_SERVICES)
clean_df['NUMBER_OF_HCPCS'] = np.log(clean_df.NUMBER_OF_HCPCS)

# %%
## Statsmodel OLS with feature engineering
# (Variable naming clarification: with_fe means with feature engineering)

formula = ols_formula(clean_df, 'TOTAL_MEDICARE_PAYMENT_AMT')
y, X = patsy.dmatrices(formula, data=clean_df, return_type="dataframe",)
model_with_fe = sm.OLS(y, X)
fit_with_fe = model_with_fe.fit()
fit_with_fe.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     TOTAL_MEDICARE_PAYMENT_AMT   R-squared:                       0.920
# Model:                                    OLS   Adj. R-squared:                  0.920
# Method:                         Least Squares   F-statistic:                 6.651e+04
# Date:                        Tue, 16 Jul 2019   Prob (F-statistic):               0.00
# Time:                                13:46:49   Log-Likelihood:            -5.5757e+05
# No. Observations:                      984927   AIC:                         1.115e+06
# Df Residuals:                          984756   BIC:                         1.117e+06
# Df Model:                                 170
# Covariance Type:                    nonrobust
# ===================================================================================================================================
#                                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                           4.7948      0.035    137.108      0.000       4.726       4.863
# NPPES_PROVIDER_GENDER[T.M]                                          0.0351      0.001     34.806      0.000       0.033       0.037
# NPPES_PROVIDER_STATE[T.AL]                                         -0.4031      0.009    -42.711      0.000      -0.422      -0.385
# NPPES_PROVIDER_STATE[T.AR]                                         -0.3961      0.010    -39.987      0.000      -0.415      -0.377
# NPPES_PROVIDER_STATE[T.AZ]                                         -0.2104      0.009    -22.886      0.000      -0.228      -0.192
# NPPES_PROVIDER_STATE[T.CA]                                         -0.1583      0.009    -17.985      0.000      -0.176      -0.141
# NPPES_PROVIDER_STATE[T.CO]                                         -0.2227      0.009    -24.019      0.000      -0.241      -0.205
# NPPES_PROVIDER_STATE[T.CT]                                         -0.2233      0.009    -23.850      0.000      -0.242      -0.205
# NPPES_PROVIDER_STATE[T.DC]                                         -0.2117      0.011    -18.560      0.000      -0.234      -0.189
# NPPES_PROVIDER_STATE[T.DE]                                         -0.2153      0.011    -19.174      0.000      -0.237      -0.193
# NPPES_PROVIDER_STATE[T.FL]                                         -0.2145      0.009    -24.162      0.000      -0.232      -0.197
# NPPES_PROVIDER_STATE[T.GA]                                         -0.2887      0.009    -31.822      0.000      -0.307      -0.271
# NPPES_PROVIDER_STATE[T.HI]                                         -0.2149      0.011    -18.710      0.000      -0.237      -0.192
# NPPES_PROVIDER_STATE[T.IA]                                         -0.3360      0.010    -34.935      0.000      -0.355      -0.317
# NPPES_PROVIDER_STATE[T.ID]                                         -0.3259      0.011    -30.843      0.000      -0.347      -0.305
# NPPES_PROVIDER_STATE[T.IL]                                         -0.2374      0.009    -26.606      0.000      -0.255      -0.220
# NPPES_PROVIDER_STATE[T.IN]                                         -0.3304      0.009    -35.974      0.000      -0.348      -0.312
# NPPES_PROVIDER_STATE[T.KS]                                         -0.3145      0.010    -32.566      0.000      -0.333      -0.296
# NPPES_PROVIDER_STATE[T.KY]                                         -0.4117      0.009    -43.914      0.000      -0.430      -0.393
# NPPES_PROVIDER_STATE[T.LA]                                         -0.3194      0.009    -33.926      0.000      -0.338      -0.301
# NPPES_PROVIDER_STATE[T.MA]                                         -0.2405      0.009    -26.721      0.000      -0.258      -0.223
# NPPES_PROVIDER_STATE[T.MD]                                         -0.1420      0.009    -15.473      0.000      -0.160      -0.124
# NPPES_PROVIDER_STATE[T.ME]                                         -0.3071      0.010    -30.006      0.000      -0.327      -0.287
# NPPES_PROVIDER_STATE[T.MI]                                         -0.3024      0.009    -33.772      0.000      -0.320      -0.285
# NPPES_PROVIDER_STATE[T.MN]                                         -0.3522      0.009    -38.641      0.000      -0.370      -0.334
# NPPES_PROVIDER_STATE[T.MO]                                         -0.3310      0.009    -36.018      0.000      -0.349      -0.313
# NPPES_PROVIDER_STATE[T.MS]                                         -0.3923      0.010    -39.456      0.000      -0.412      -0.373
# NPPES_PROVIDER_STATE[T.MT]                                         -0.2465      0.011    -22.266      0.000      -0.268      -0.225
# NPPES_PROVIDER_STATE[T.NC]                                         -0.3027      0.009    -33.696      0.000      -0.320      -0.285
# NPPES_PROVIDER_STATE[T.ND]                                         -0.3948      0.011    -34.518      0.000      -0.417      -0.372
# NPPES_PROVIDER_STATE[T.NE]                                         -0.3281      0.010    -32.644      0.000      -0.348      -0.308
# NPPES_PROVIDER_STATE[T.NH]                                         -0.2285      0.010    -22.174      0.000      -0.249      -0.208
# NPPES_PROVIDER_STATE[T.NJ]                                         -0.1342      0.009    -14.828      0.000      -0.152      -0.116
# NPPES_PROVIDER_STATE[T.NM]                                         -0.2900      0.010    -28.203      0.000      -0.310      -0.270
# NPPES_PROVIDER_STATE[T.NV]                                         -0.1708      0.010    -16.814      0.000      -0.191      -0.151
# NPPES_PROVIDER_STATE[T.NY]                                         -0.1633      0.009    -18.473      0.000      -0.181      -0.146
# NPPES_PROVIDER_STATE[T.OH]                                         -0.3257      0.009    -36.442      0.000      -0.343      -0.308
# NPPES_PROVIDER_STATE[T.OK]                                         -0.3345      0.010    -34.904      0.000      -0.353      -0.316
# NPPES_PROVIDER_STATE[T.OR]                                         -0.2939      0.009    -31.120      0.000      -0.312      -0.275
# NPPES_PROVIDER_STATE[T.PA]                                         -0.2691      0.009    -30.265      0.000      -0.286      -0.252
# NPPES_PROVIDER_STATE[T.RI]                                         -0.2714      0.011    -25.167      0.000      -0.293      -0.250
# NPPES_PROVIDER_STATE[T.SC]                                         -0.3419      0.009    -36.393      0.000      -0.360      -0.324
# NPPES_PROVIDER_STATE[T.SD]                                         -0.3651      0.011    -32.575      0.000      -0.387      -0.343
# NPPES_PROVIDER_STATE[T.TN]                                         -0.3596      0.009    -39.420      0.000      -0.377      -0.342
# NPPES_PROVIDER_STATE[T.TX]                                         -0.2910      0.009    -32.860      0.000      -0.308      -0.274
# NPPES_PROVIDER_STATE[T.UT]                                         -0.2477      0.010    -24.738      0.000      -0.267      -0.228
# NPPES_PROVIDER_STATE[T.VA]                                         -0.2624      0.009    -28.822      0.000      -0.280      -0.245
# NPPES_PROVIDER_STATE[T.VT]                                         -0.2934      0.012    -24.644      0.000      -0.317      -0.270
# NPPES_PROVIDER_STATE[T.WA]                                         -0.2606      0.009    -28.700      0.000      -0.278      -0.243
# NPPES_PROVIDER_STATE[T.WI]                                         -0.3573      0.009    -39.107      0.000      -0.375      -0.339
# NPPES_PROVIDER_STATE[T.WV]                                         -0.4081      0.010    -39.887      0.000      -0.428      -0.388
# NPPES_PROVIDER_STATE[T.WY]                                         -0.2775      0.013    -21.041      0.000      -0.303      -0.252
# PROVIDER_TYPE[T.All Other Suppliers]                               -0.6715      0.303     -2.214      0.027      -1.266      -0.077
# PROVIDER_TYPE[T.Allergy/ Immunology]                               -0.7391      0.034    -21.794      0.000      -0.806      -0.673
# PROVIDER_TYPE[T.Ambulance Service Provider]                         0.1921      0.146      1.317      0.188      -0.094       0.478
# PROVIDER_TYPE[T.Anesthesiology]                                     0.2188      0.033      6.602      0.000       0.154       0.284
# PROVIDER_TYPE[T.Anesthesiology Assistant]                          -0.0171      0.035     -0.495      0.620      -0.085       0.051
# PROVIDER_TYPE[T.Audiologist]                                       -1.1091      0.033    -33.108      0.000      -1.175      -1.043
# PROVIDER_TYPE[T.Cardiac Surgery]                                    1.1587      0.035     33.134      0.000       1.090       1.227
# PROVIDER_TYPE[T.Cardiovascular Disease (Cardiology)]               -0.2533      0.033     -7.626      0.000      -0.318      -0.188
# PROVIDER_TYPE[T.Certified Clinical Nurse Specialist]               -0.2576      0.034     -7.510      0.000      -0.325      -0.190
# PROVIDER_TYPE[T.Certified Nurse Midwife]                           -0.5570      0.036    -15.445      0.000      -0.628      -0.486
# PROVIDER_TYPE[T.Certified Registered Nurse Anesthetist (CRNA)]      0.1502      0.033      4.532      0.000       0.085       0.215
# PROVIDER_TYPE[T.Chiropractic]                                      -0.4003      0.033    -12.075      0.000      -0.465      -0.335
# PROVIDER_TYPE[T.Clinic or Group Practice]                          -0.2526      0.069     -3.645      0.000      -0.388      -0.117
# PROVIDER_TYPE[T.Clinical Cardiatric Electrophysiology]             -0.0827      0.035     -2.391      0.017      -0.150      -0.015
# PROVIDER_TYPE[T.Clinical Laboratory]                               -1.0318      0.115     -8.976      0.000      -1.257      -0.807
# PROVIDER_TYPE[T.Colorectal Surgery (Proctology)]                    0.6379      0.035     18.252      0.000       0.569       0.706
# PROVIDER_TYPE[T.Critical Care (Intensivists)]                       0.1634      0.034      4.810      0.000       0.097       0.230
# PROVIDER_TYPE[T.Dentist]                                            2.0220      0.303      6.668      0.000       1.428       2.616
# PROVIDER_TYPE[T.Dermatology]                                       -0.0284      0.033     -0.852      0.394      -0.094       0.037
# PROVIDER_TYPE[T.Diagnostic Radiology]                              -1.0328      0.033    -31.079      0.000      -1.098      -0.968
# PROVIDER_TYPE[T.Emergency Medicine]                                -0.1022      0.033     -3.085      0.002      -0.167      -0.037
# PROVIDER_TYPE[T.Endocrinology]                                     -0.2627      0.034     -7.825      0.000      -0.329      -0.197
# PROVIDER_TYPE[T.Family Practice]                                   -0.3653      0.033    -11.046      0.000      -0.430      -0.300
# PROVIDER_TYPE[T.Gastroenterology]                                   0.1683      0.033      5.061      0.000       0.103       0.234
# PROVIDER_TYPE[T.General Practice]                                  -0.2241      0.034     -6.666      0.000      -0.290      -0.158
# PROVIDER_TYPE[T.General Surgery]                                    0.5358      0.033     16.139      0.000       0.471       0.601
# PROVIDER_TYPE[T.Geriatric Medicine]                                -0.1703      0.035     -4.933      0.000      -0.238      -0.103
# PROVIDER_TYPE[T.Geriatric Psychiatry]                              -0.0997      0.045     -2.234      0.025      -0.187      -0.012
# PROVIDER_TYPE[T.Gynecological Oncology]                             0.3839      0.036     10.713      0.000       0.314       0.454
# PROVIDER_TYPE[T.Hand Surgery]                                       0.2058      0.035      5.882      0.000       0.137       0.274
# PROVIDER_TYPE[T.Hematology]                                        -0.1184      0.037     -3.225      0.001      -0.190      -0.046
# PROVIDER_TYPE[T.Hematology-Oncology]                               -0.2625      0.033     -7.851      0.000      -0.328      -0.197
# PROVIDER_TYPE[T.Hospice and Palliative Care]                       -0.1828      0.036     -5.099      0.000      -0.253      -0.113
# PROVIDER_TYPE[T.Hospitalist]                                        0.0024      0.303      0.008      0.994      -0.592       0.597
# PROVIDER_TYPE[T.Independent Diagnostic Testing Facility (IDTF)]     0.0496      0.146      0.340      0.734      -0.236       0.336
# PROVIDER_TYPE[T.Infectious Disease]                                -0.2441      0.034     -7.279      0.000      -0.310      -0.178
# PROVIDER_TYPE[T.Internal Medicine]                                 -0.1804      0.033     -5.455      0.000      -0.245      -0.116
# PROVIDER_TYPE[T.Interventional Cardiology]                         -0.0376      0.034     -1.100      0.271      -0.105       0.029
# PROVIDER_TYPE[T.Interventional Pain Management]                     0.1080      0.035      3.116      0.002       0.040       0.176
# PROVIDER_TYPE[T.Interventional Radiology]                          -0.3275      0.035     -9.386      0.000      -0.396      -0.259
# PROVIDER_TYPE[T.Licensed Clinical Social Worker]                    0.1374      0.033      4.144      0.000       0.072       0.202
# PROVIDER_TYPE[T.Mass Immunizer Roster Biller]                      -0.7025      0.087     -8.068      0.000      -0.873      -0.532
# PROVIDER_TYPE[T.Maxillofacial Surgery]                              0.3629      0.036     10.116      0.000       0.293       0.433
# PROVIDER_TYPE[T.Medical Oncology]                                  -0.2088      0.034     -6.140      0.000      -0.275      -0.142
# PROVIDER_TYPE[T.Nephrology]                                         0.1165      0.033      3.486      0.000       0.051       0.182
# PROVIDER_TYPE[T.Neurology]                                         -0.1624      0.033     -4.884      0.000      -0.228      -0.097
# PROVIDER_TYPE[T.Neuropsychiatry]                                   -0.0100      0.051     -0.196      0.845      -0.110       0.090
# PROVIDER_TYPE[T.Neurosurgery]                                       0.9574      0.034     28.446      0.000       0.891       1.023
# PROVIDER_TYPE[T.Nuclear Medicine]                                  -0.3208      0.038     -8.486      0.000      -0.395      -0.247
# PROVIDER_TYPE[T.Nurse Practitioner]                                -0.5599      0.033    -16.937      0.000      -0.625      -0.495
# PROVIDER_TYPE[T.Obstetrics & Gynecology]                           -0.1535      0.033     -4.634      0.000      -0.218      -0.089
# PROVIDER_TYPE[T.Occupational Therapist in Private Practice]        -0.3943      0.034    -11.730      0.000      -0.460      -0.328
# PROVIDER_TYPE[T.Ophthalmology]                                      0.4360      0.033     13.124      0.000       0.371       0.501
# PROVIDER_TYPE[T.Optometry]                                         -0.2704      0.033     -8.157      0.000      -0.335      -0.205
# PROVIDER_TYPE[T.Oral Surgery (Dentists only)]                       0.3459      0.035      9.904      0.000       0.277       0.414
# PROVIDER_TYPE[T.Orthopedic Surgery]                                 0.2619      0.033      7.891      0.000       0.197       0.327
# PROVIDER_TYPE[T.Osteopathic Manipulative Medicine]                 -0.0635      0.037     -1.708      0.088      -0.136       0.009
# PROVIDER_TYPE[T.Otolaryngology]                                     0.0834      0.033      2.498      0.012       0.018       0.149
# PROVIDER_TYPE[T.Pain Management]                                    0.0834      0.034      2.428      0.015       0.016       0.151
# PROVIDER_TYPE[T.Pathology]                                         -0.7178      0.033    -21.561      0.000      -0.783      -0.653
# PROVIDER_TYPE[T.Pediatric Medicine]                                -0.2907      0.034     -8.460      0.000      -0.358      -0.223
# PROVIDER_TYPE[T.Peripheral Vascular Disease]                        0.1007      0.065      1.539      0.124      -0.028       0.229
# PROVIDER_TYPE[T.Physical Medicine and Rehabilitation]              -0.1359      0.033     -4.068      0.000      -0.201      -0.070
# PROVIDER_TYPE[T.Physical Therapist in Private Practice]            -0.3720      0.033    -11.233      0.000      -0.437      -0.307
# PROVIDER_TYPE[T.Physician Assistant]                               -0.5021      0.033    -15.179      0.000      -0.567      -0.437
# PROVIDER_TYPE[T.Plastic and Reconstructive Surgery]                 0.7961      0.034     23.633      0.000       0.730       0.862
# PROVIDER_TYPE[T.Podiatry]                                          -0.2714      0.033     -8.163      0.000      -0.337      -0.206
# PROVIDER_TYPE[T.Portable X-Ray Supplier]                           -0.2954      0.164     -1.796      0.073      -0.618       0.027
# PROVIDER_TYPE[T.Preventive Medicine]                               -0.3286      0.040     -8.130      0.000      -0.408      -0.249
# PROVIDER_TYPE[T.Psychiatry]                                        -0.0525      0.033     -1.583      0.113      -0.117       0.012
# PROVIDER_TYPE[T.Psychologist, Clinical]                             0.3356      0.033     10.111      0.000       0.271       0.401
# PROVIDER_TYPE[T.Pulmonary Disease]                                 -0.0442      0.033     -1.324      0.185      -0.110       0.021
# PROVIDER_TYPE[T.Radiation Oncology]                                 0.4948      0.034     14.620      0.000       0.428       0.561
# PROVIDER_TYPE[T.Registered Dietitian or Nutrition Professional]    -0.5040      0.034    -14.609      0.000      -0.572      -0.436
# PROVIDER_TYPE[T.Rheumatology]                                      -0.2274      0.034     -6.751      0.000      -0.293      -0.161
# PROVIDER_TYPE[T.Sleep Medicine]                                     0.2155      0.040      5.331      0.000       0.136       0.295
# PROVIDER_TYPE[T.Slide Preparation Facility]                        -0.7156      0.428     -1.674      0.094      -1.554       0.122
# PROVIDER_TYPE[T.Speech Language Pathologist]                        0.2645      0.036      7.303      0.000       0.194       0.335
# PROVIDER_TYPE[T.Sports Medicine]                                   -0.1709      0.036     -4.785      0.000      -0.241      -0.101
# PROVIDER_TYPE[T.Surgical Oncology]                                  0.7131      0.036     19.786      0.000       0.643       0.784
# PROVIDER_TYPE[T.Thoracic Surgery]                                   1.0160      0.034     29.570      0.000       0.949       1.083
# PROVIDER_TYPE[T.Undefined Physician type]                          -0.0263      0.042     -0.634      0.526      -0.108       0.055
# PROVIDER_TYPE[T.Unknown Supplier/Provider Specialty]               -0.0371      0.127     -0.291      0.771      -0.287       0.213
# PROVIDER_TYPE[T.Urology]                                           -0.1856      0.033     -5.554      0.000      -0.251      -0.120
# PROVIDER_TYPE[T.Vascular Surgery]                                   0.4856      0.034     14.301      0.000       0.419       0.552
# NUMBER_OF_HCPCS                                                     0.0487      0.001     59.218      0.000       0.047       0.050
# TOTAL_SERVICES                                                      0.6543      0.001    954.362      0.000       0.653       0.656
# TOTAL_UNIQUE_BENES                                                  0.2806      0.001    252.876      0.000       0.278       0.283
# BENEFICIARY_AVERAGE_AGE                                            -0.0005      0.000     -4.437      0.000      -0.001      -0.000
# BENEFICIARY_AGE_LESS_65_COUNT                                      -0.0003   2.15e-05    -12.096      0.000      -0.000      -0.000
# BENEFICIARY_AGE_65_74_COUNT                                       3.87e-06   1.82e-05      0.212      0.832   -3.18e-05    3.96e-05
# BENEFICIARY_AGE_75_84_COUNT                                         0.0003   2.34e-05     10.963      0.000       0.000       0.000
# BENEFICIARY_AGE_GREATER_84_COUNT                                   -0.0004   2.17e-05    -17.563      0.000      -0.000      -0.000
# BENEFICIARY_FEMALE_COUNT                                           -0.0001    1.2e-05    -11.603      0.000      -0.000      -0.000
# BENEFICIARY_MALE_COUNT                                             -0.0003   1.31e-05    -21.724      0.000      -0.000      -0.000
# BENEFICIARY_RACE_WHITE_COUNT                                        0.0002   8.14e-06     20.133      0.000       0.000       0.000
# BENEFICIARY_RACE_BLACK_COUNT                                        0.0002   1.04e-05     14.668      0.000       0.000       0.000
# BENEFICIARY_RACE_API_COUNT                                          0.0004   1.75e-05     23.090      0.000       0.000       0.000
# BENEFICIARY_RACE_HISPANIC_COUNT                                     0.0001   1.24e-05     11.543      0.000       0.000       0.000
# BENEFICIARY_RACE_NATIND_COUNT                                    5.008e-06   3.61e-05      0.139      0.890   -6.57e-05    7.57e-05
# BENEFICIARY_RACE_OTHER_COUNT                                    -6.275e-05   6.39e-05     -0.983      0.326      -0.000    6.24e-05
# BENEFICIARY_NONDUAL_COUNT                                        8.172e-07   8.39e-06      0.097      0.922   -1.56e-05    1.73e-05
# BENEFICIARY_DUAL_COUNT                                           -1.57e-05    1.2e-05     -1.314      0.189   -3.91e-05    7.73e-06
# BENEFICIARY_CC_AFIB_PERCENT                                        -0.0019   8.37e-05    -23.072      0.000      -0.002      -0.002
# BENEFICIARY_CC_ALZRDSD_PERCENT                                      0.0021   5.69e-05     36.766      0.000       0.002       0.002
# BENEFICIARY_CC_ASTHMA_PERCENT                                      -0.0008   8.84e-05     -8.969      0.000      -0.001      -0.001
# BENEFICIARY_CC_CANCER_PERCENT                                       0.0035   6.33e-05     56.010      0.000       0.003       0.004
# BENEFICIARY_CC_CHF_PERCENT                                          0.0041   6.69e-05     61.406      0.000       0.004       0.004
# BENEFICIARY_CC_CKD_PERCENT                                          0.0026   5.09e-05     51.602      0.000       0.003       0.003
# BENEFICIARY_CC_COPD_PERCENT                                         0.0001    9.5e-05      1.426      0.154   -5.07e-05       0.000
# BENEFICIARY_CC_DEPR_PERCENT                                         0.0027    4.1e-05     66.961      0.000       0.003       0.003
# BENEFICIARY_CC_DIAB_PERCENT                                        -0.0041   4.82e-05    -85.065      0.000      -0.004      -0.004
# BENEFICIARY_CC_HYPERL_PERCENT                                       0.0012   4.16e-05     28.597      0.000       0.001       0.001
# BENEFICIARY_CC_HYPERT_PERCENT                                      -0.0011   4.24e-05    -24.846      0.000      -0.001      -0.001
# BENEFICIARY_CC_IHD_PERCENT                                          0.0021   5.24e-05     40.746      0.000       0.002       0.002
# BENEFICIARY_CC_OST_PERCENT                                          0.0012   9.53e-05     12.583      0.000       0.001       0.001
# BENEFICIARY_CC_RAOA_PERCENT                                         0.0014   3.73e-05     37.644      0.000       0.001       0.001
# BENEFICIARY_CC_SCHIOT_PERCENT                                       0.0002   6.28e-05      2.521      0.012    3.52e-05       0.000
# BENEFICIARY_CC_STRK_PERCENT                                         0.0036   9.01e-05     40.078      0.000       0.003       0.004
# ==============================================================================
# Omnibus:                   204911.687   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1375180.005
# Skew:                          -0.837   Prob(JB):                         0.00
# Kurtosis:                       8.541   Cond. No.                     9.63e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.63e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
### Running OLS and Ridge Regression

# Removing 20% of the data for final testing
X, X_test, y, y_test = train_test_split(X, y, test_size=.4, random_state=10)

# Splitting into val and train sets
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=.25, random_state=11)

# Scaling features for Ridge Regression
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train.values)
X_val_scaled = scaler.transform(X_val.values)
X_test_scaled = scaler.transform(X_test.values)

#Setting up OLS and Ridge Regression
lm = LinearRegression()
lm_reg = Ridge()

# Training and testing
lm.fit(X_train, y_train)
print(f'Linear Regression val R^2: {lm.score(X_val, y_val):.3f}')

lm_reg.fit(X_train_scaled, y_train)
print(f'Ridge Regression val R^2: {lm_reg.score(X_val_scaled, y_val):.3f}')
# Out:
# Linear Regression val R^2: 0.920
# Ridge Regression val R^2: 0.920

# %%
residual_normality_visualizations(fit_with_fe.predict(),fit_with_fe.resid)

# Q-Q Plot:Tails still not fitting a normal distribution
# Predicted vs Residuals: Residuals looking more normally distributed now

# %%
# R Squared of Ridge Model on out of sample test data
# Since it is very similar to in sample r-squared this 
# means it is generalizable to unseen data
lm_reg.score(X_test_scaled, y_test)
# Out:
# 0.9199198080946224

# %% [markdown]
# ## Final Modeling
# - Choosing between LASSO and RIDGE regression using cross validation and hyperparameter tuning

# %% [markdown]
# ### LASSO Regression

# %%
# Creating X and y
formula = ols_formula(clean_df, 'TOTAL_MEDICARE_PAYMENT_AMT')
y, X = patsy.dmatrices(formula, data=clean_df, return_type="dataframe")
# Setting up test and train split
X, X_test, y, y_test = train_test_split(X, y, test_size=.4, random_state=10)

# Scaling X and X_test for lasso
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X.values)
X_test_scaled = scaler.transform(X_test.values)

# Running Model and finding most optimal alpha
alphavec = 10**np.linspace(-5,2,8)

lm_lasso = LassoCV(alphas = alphavec, cv=5)
lm_lasso.fit(X_train_scaled, y)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:1109: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# LassoCV(alphas=array([1.e-05, 1.e-04, 1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02]),
#     copy_X=True, cv=5, eps=0.001, fit_intercept=True, max_iter=1000,
#     n_alphas=100, n_jobs=None, normalize=False, positive=False,
#     precompute='auto', random_state=None, selection='cyclic', tol=0.0001,
#     verbose=False)

# %%
# The best alpha for the lasso model
lm_lasso.alpha_

# This is a very small alpha indicating that adding
# regularization to the loss function possibly 
# diminishes out of sample scores
# Out:
# 1e-05

# %%
# Making predictions on the test set using the new LASSO model
y_prediction = lm_lasso.predict(X_test_scaled)

# %%
# r2 of LASSO model on test set
r2_score(y_test, y_prediction)
# Out:
# 0.9199271631927486

# %%
# LASSO did not zero out many of the features as expected
# indicating most features add predictability to the model
list(zip(X.columns, lm_lasso.coef_))
# Out:
# [('Intercept', 0.0),
#  ('NPPES_PROVIDER_GENDER[T.M]', 0.017360158013801953),
#  ('NPPES_PROVIDER_STATE[T.AL]', -0.04319333158460671),
#  ('NPPES_PROVIDER_STATE[T.AR]', -0.032577237039541254),
#  ('NPPES_PROVIDER_STATE[T.AZ]', -0.024491339948137694),
#  ('NPPES_PROVIDER_STATE[T.CA]', -0.03478529926898068),
#  ('NPPES_PROVIDER_STATE[T.CO]', -0.024835325759719813),
#  ('NPPES_PROVIDER_STATE[T.CT]', -0.023391616237317094),
#  ('NPPES_PROVIDER_STATE[T.DC]', -0.009975621816022445),
#  ('NPPES_PROVIDER_STATE[T.DE]', -0.010638265427360391),
#  ('NPPES_PROVIDER_STATE[T.FL]', -0.04386821958754966),
#  ('NPPES_PROVIDER_STATE[T.GA]', -0.04153446589011618),
#  ('NPPES_PROVIDER_STATE[T.HI]', -0.010231941514229482),
#  ('NPPES_PROVIDER_STATE[T.IA]', -0.03134177420466352),
#  ('NPPES_PROVIDER_STATE[T.ID]', -0.02093761195782934),
#  ('NPPES_PROVIDER_STATE[T.IL]', -0.041264107547081194),
#  ('NPPES_PROVIDER_STATE[T.IN]', -0.0422391658943246),
#  ('NPPES_PROVIDER_STATE[T.KS]', -0.02893300600097858),
#  ('NPPES_PROVIDER_STATE[T.KY]', -0.046864548343452356),
#  ('NPPES_PROVIDER_STATE[T.LA]', -0.03458376317931576),
#  ('NPPES_PROVIDER_STATE[T.MA]', -0.0368097043130329),
#  ('NPPES_PROVIDER_STATE[T.MD]', -0.015257779406123712),
#  ('NPPES_PROVIDER_STATE[T.ME]', -0.022051743192010274),
#  ('NPPES_PROVIDER_STATE[T.MI]', -0.05207208092652719),
#  ('NPPES_PROVIDER_STATE[T.MN]', -0.048683975480314765),
#  ('NPPES_PROVIDER_STATE[T.MO]', -0.04217936414322761),
#  ('NPPES_PROVIDER_STATE[T.MS]', -0.031774975896625555),
#  ('NPPES_PROVIDER_STATE[T.MT]', -0.013217545719996879),
#  ('NPPES_PROVIDER_STATE[T.NC]', -0.04864295342020155),
#  ('NPPES_PROVIDER_STATE[T.ND]', -0.02075462399567808),
#  ('NPPES_PROVIDER_STATE[T.NE]', -0.02508234168944223),
#  ('NPPES_PROVIDER_STATE[T.NH]', -0.01506300292766319),
#  ('NPPES_PROVIDER_STATE[T.NJ]', -0.017140299197592863),
#  ('NPPES_PROVIDER_STATE[T.NM]', -0.020340014317783883),
#  ('NPPES_PROVIDER_STATE[T.NV]', -0.011339874114319422),
#  ('NPPES_PROVIDER_STATE[T.NY]', -0.0343268270910204),
#  ('NPPES_PROVIDER_STATE[T.OH]', -0.05796332104628267),
#  ('NPPES_PROVIDER_STATE[T.OK]', -0.031244120790554025),
#  ('NPPES_PROVIDER_STATE[T.OR]', -0.029504306931308465),
#  ('NPPES_PROVIDER_STATE[T.PA]', -0.05218650468116309),
#  ('NPPES_PROVIDER_STATE[T.RI]', -0.015917754409115446),
#  ('NPPES_PROVIDER_STATE[T.SC]', -0.03702887048310025),
#  ('NPPES_PROVIDER_STATE[T.SD]', -0.020262389865711463),
#  ('NPPES_PROVIDER_STATE[T.TN]', -0.04914169110696766),
#  ('NPPES_PROVIDER_STATE[T.TX]', -0.06326396380815363),
#  ('NPPES_PROVIDER_STATE[T.UT]', -0.019435988291237282),
#  ('NPPES_PROVIDER_STATE[T.VA]', -0.03546171722722094),
#  ('NPPES_PROVIDER_STATE[T.VT]', -0.01339188638292878),
#  ('NPPES_PROVIDER_STATE[T.WA]', -0.03490703412894527),
#  ('NPPES_PROVIDER_STATE[T.WI]', -0.04730501564130188),
#  ('NPPES_PROVIDER_STATE[T.WV]', -0.030856275861793164),
#  ('NPPES_PROVIDER_STATE[T.WY]', -0.010454479556852863),
#  ('PROVIDER_TYPE[T.All Other Suppliers]', -0.0009761614757470474),
#  ('PROVIDER_TYPE[T.Allergy/ Immunology]', -0.03552532335783599),
#  ('PROVIDER_TYPE[T.Ambulance Service Provider]', 0.0010168083889632985),
#  ('PROVIDER_TYPE[T.Anesthesiology]', 0.06593257173080028),
#  ('PROVIDER_TYPE[T.Anesthesiology Assistant]', 0.004416711347837393),
#  ('PROVIDER_TYPE[T.Audiologist]', -0.07714072804123619),
#  ('PROVIDER_TYPE[T.Cardiac Surgery]', 0.0486971589111726),
#  ('PROVIDER_TYPE[T.Cardiovascular Disease (Cardiology)]',
#   -0.017621513276209696),
#  ('PROVIDER_TYPE[T.Certified Clinical Nurse Specialist]',
#   -0.005770897053972881),
#  ('PROVIDER_TYPE[T.Certified Nurse Midwife]', -0.013078263108458103),
#  ('PROVIDER_TYPE[T.Certified Registered Nurse Anesthetist (CRNA)]',
#   0.05632696321729992),
#  ('PROVIDER_TYPE[T.Chiropractic]', -0.04899277102237581),
#  ('PROVIDER_TYPE[T.Clinic or Group Practice]', -0.0006667258617638103),
#  ('PROVIDER_TYPE[T.Clinical Cardiatric Electrophysiology]',
#   0.00141691586671795),
#  ('PROVIDER_TYPE[T.Clinical Laboratory]', -0.0029188789680561532),
#  ('PROVIDER_TYPE[T.Colorectal Surgery (Proctology)]', 0.02922468511431282),
#  ('PROVIDER_TYPE[T.Critical Care (Intensivists)]', 0.016013048716752444),
#  ('PROVIDER_TYPE[T.Dentist]', 0.0032453812748601896),
#  ('PROVIDER_TYPE[T.Dermatology]', 0.011111204015787038),
#  ('PROVIDER_TYPE[T.Diagnostic Radiology]', -0.15483496574655195),
#  ('PROVIDER_TYPE[T.Emergency Medicine]', 0.0048622065761943665),
#  ('PROVIDER_TYPE[T.Endocrinology]', -0.010201028847632404),
#  ('PROVIDER_TYPE[T.Family Practice]', -0.06573226764300924),
#  ('PROVIDER_TYPE[T.Gastroenterology]', 0.03353695955693799),
#  ('PROVIDER_TYPE[T.General Practice]', -0.006335885899343455),
#  ('PROVIDER_TYPE[T.General Surgery]', 0.09368522572732098),
#  ('PROVIDER_TYPE[T.Geriatric Medicine]', -0.001633137003264692),
#  ('PROVIDER_TYPE[T.Geriatric Psychiatry]', 0.00024365633072125314),
#  ('PROVIDER_TYPE[T.Gynecological Oncology]', 0.016823412759549437),
#  ('PROVIDER_TYPE[T.Hand Surgery]', 0.0123150831997733),
#  ('PROVIDER_TYPE[T.Hematology]', 0.0005418524153392076),
#  ('PROVIDER_TYPE[T.Hematology-Oncology]', -0.012453218378994631),
#  ('PROVIDER_TYPE[T.Hospice and Palliative Care]', -0.0017152628697885612),
#  ('PROVIDER_TYPE[T.Hospitalist]', 0.00021733885478396176),
#  ('PROVIDER_TYPE[T.Independent Diagnostic Testing Facility (IDTF)]',
#   -0.00011640403359830855),
#  ('PROVIDER_TYPE[T.Infectious Disease]', -0.008899115148970753),
#  ('PROVIDER_TYPE[T.Internal Medicine]', -0.0154855216719889),
#  ('PROVIDER_TYPE[T.Interventional Cardiology]', 0.004385555710883982),
#  ('PROVIDER_TYPE[T.Interventional Pain Management]', 0.009655241389107585),
#  ('PROVIDER_TYPE[T.Interventional Radiology]', -0.00839929598203502),
#  ('PROVIDER_TYPE[T.Licensed Clinical Social Worker]', 0.037189596608354705),
#  ('PROVIDER_TYPE[T.Mass Immunizer Roster Biller]', -0.0025552238587480207),
#  ('PROVIDER_TYPE[T.Maxillofacial Surgery]', 0.014663679696929853),
#  ('PROVIDER_TYPE[T.Medical Oncology]', -0.004588486375698867),
#  ('PROVIDER_TYPE[T.Nephrology]', 0.021686585291999138),
#  ('PROVIDER_TYPE[T.Neurology]', -0.0035739923425708083),
#  ('PROVIDER_TYPE[T.Neuropsychiatry]', 0.0012753805570527754),
#  ('PROVIDER_TYPE[T.Neurosurgery]', 0.07356808912019225),
#  ('PROVIDER_TYPE[T.Nuclear Medicine]', -0.005077986122426599),
#  ('PROVIDER_TYPE[T.Nurse Practitioner]', -0.13014584235443788),
#  ('PROVIDER_TYPE[T.Obstetrics & Gynecology]', -0.0038149599544329478),
#  ('PROVIDER_TYPE[T.Occupational Therapist in Private Practice]',
#   -0.01841566366921221),
#  ('PROVIDER_TYPE[T.Ophthalmology]', 0.07494292226884268),
#  ('PROVIDER_TYPE[T.Optometry]', -0.023530422699053102),
#  ('PROVIDER_TYPE[T.Oral Surgery (Dentists only)]', 0.017293347453999203),
#  ('PROVIDER_TYPE[T.Orthopedic Surgery]', 0.05608283177223149),
#  ('PROVIDER_TYPE[T.Osteopathic Manipulative Medicine]', 0.0018992504718056686),
#  ('PROVIDER_TYPE[T.Otolaryngology]', 0.019693611965037657),
#  ('PROVIDER_TYPE[T.Pain Management]', 0.00950836423259608),
#  ('PROVIDER_TYPE[T.Pathology]', -0.06417373372694891),
#  ('PROVIDER_TYPE[T.Pediatric Medicine]', -0.007650775800882968),
#  ('PROVIDER_TYPE[T.Peripheral Vascular Disease]', 0.0016728598820821131),
#  ('PROVIDER_TYPE[T.Physical Medicine and Rehabilitation]',
#   -0.0004817289718274072),
#  ('PROVIDER_TYPE[T.Physical Therapist in Private Practice]',
#   -0.051585946651690535),
#  ('PROVIDER_TYPE[T.Physician Assistant]', -0.09333984204679543),
#  ('PROVIDER_TYPE[T.Plastic and Reconstructive Surgery]', 0.06145533751230066),
#  ('PROVIDER_TYPE[T.Podiatry]', -0.017363290658125405),
#  ('PROVIDER_TYPE[T.Portable X-Ray Supplier]', -5.750521926790155e-05),
#  ('PROVIDER_TYPE[T.Preventive Medicine]', -0.0032736372486059794),
#  ('PROVIDER_TYPE[T.Psychiatry]', 0.011034719747769508),
#  ('PROVIDER_TYPE[T.Psychologist, Clinical]', 0.059004276626528455),
#  ('PROVIDER_TYPE[T.Pulmonary Disease]', 0.008081692980710703),
#  ('PROVIDER_TYPE[T.Radiation Oncology]', 0.041283634696789605),
#  ('PROVIDER_TYPE[T.Registered Dietitian or Nutrition Professional]',
#   -0.017358125743297738),
#  ('PROVIDER_TYPE[T.Rheumatology]', -0.006329490173020589),
#  ('PROVIDER_TYPE[T.Sleep Medicine]', 0.006537365040071711),
#  ('PROVIDER_TYPE[T.Slide Preparation Facility]', 0.0),
#  ('PROVIDER_TYPE[T.Speech Language Pathologist]', 0.011437245096890333),
#  ('PROVIDER_TYPE[T.Sports Medicine]', -0.0011973628396661344),
#  ('PROVIDER_TYPE[T.Surgical Oncology]', 0.02539222015847193),
#  ('PROVIDER_TYPE[T.Thoracic Surgery]', 0.051724995839869885),
#  ('PROVIDER_TYPE[T.Undefined Physician type]', 0.0013780059586185316),
#  ('PROVIDER_TYPE[T.Unknown Supplier/Provider Specialty]',
#   0.0006297150924373106),
#  ('PROVIDER_TYPE[T.Urology]', -0.0053844419960999935),
#  ('PROVIDER_TYPE[T.Vascular Surgery]', 0.03409489270047197),
#  ('NUMBER_OF_HCPCS', 0.054146804657554524),
#  ('TOTAL_SERVICES', 1.0234944610420316),
#  ('TOTAL_UNIQUE_BENES', 0.3522371757803613),
#  ('BENEFICIARY_AVERAGE_AGE', -0.002875617364557411),
#  ('BENEFICIARY_AGE_LESS_65_COUNT', -0.02536786304959985),
#  ('BENEFICIARY_AGE_65_74_COUNT', -0.0010423988258051369),
#  ('BENEFICIARY_AGE_75_84_COUNT', 0.04511916842681628),
#  ('BENEFICIARY_AGE_GREATER_84_COUNT', -0.03914603274747871),
#  ('BENEFICIARY_FEMALE_COUNT', -0.04726683933745655),
#  ('BENEFICIARY_MALE_COUNT', -0.06822761066730894),
#  ('BENEFICIARY_RACE_WHITE_COUNT', 0.07856652521601108),
#  ('BENEFICIARY_RACE_BLACK_COUNT', 0.013032731622164083),
#  ('BENEFICIARY_RACE_API_COUNT', 0.01303352550102305),
#  ('BENEFICIARY_RACE_HISPANIC_COUNT', 0.009672191880891055),
#  ('BENEFICIARY_RACE_NATIND_COUNT', 0.00014698271944734353),
#  ('BENEFICIARY_RACE_OTHER_COUNT', -0.0007823670243393734),
#  ('BENEFICIARY_NONDUAL_COUNT', 0.0019603800449951264),
#  ('BENEFICIARY_DUAL_COUNT', -0.0031838533819745665),
#  ('BENEFICIARY_CC_AFIB_PERCENT', -0.01968087097196463),
#  ('BENEFICIARY_CC_ALZRDSD_PERCENT', 0.029642154274317017),
#  ('BENEFICIARY_CC_ASTHMA_PERCENT', -0.012012527909699),
#  ('BENEFICIARY_CC_CANCER_PERCENT', 0.03652184621814734),
#  ('BENEFICIARY_CC_CHF_PERCENT', 0.07197167946029127),
#  ('BENEFICIARY_CC_CKD_PERCENT', 0.05639256944075437),
#  ('BENEFICIARY_CC_COPD_PERCENT', 0.0029329640520473063),
#  ('BENEFICIARY_CC_DEPR_PERCENT', 0.04961471872294377),
#  ('BENEFICIARY_CC_DIAB_PERCENT', -0.07157040956057585),
#  ('BENEFICIARY_CC_HYPERL_PERCENT', 0.0235779750995629),
#  ('BENEFICIARY_CC_HYPERT_PERCENT', -0.020609352485352766),
#  ('BENEFICIARY_CC_IHD_PERCENT', 0.04317223025135987),
#  ('BENEFICIARY_CC_OST_PERCENT', 0.007331111710984612),
#  ('BENEFICIARY_CC_RAOA_PERCENT', 0.026393492325077452),
#  ('BENEFICIARY_CC_SCHIOT_PERCENT', 0.0019176020742533233),
#  ('BENEFICIARY_CC_STRK_PERCENT', 0.026622428013836616)]

# %%
# Mean absolute error (MAE)
# This value shows on average how off
# my model is from the true value
np.abs(np.e**(y_prediction) - np.e**(y_test.iloc[:,0])).mean()
# Out:
# 26682.443908140576

# %%
# Root Mean Squared Error (RMSE)
# Similar to MAE except largely affected by outliers.
# This RMSE is about 5 times greater than the MAE,
# indicating a strong presence of outliers
np.sqrt(mean_squared_error(np.e**(y_test), np.e**(y_prediction)))
# Out:
# 116386.54528772678

# %%
# Finding residuals of test data vs prediction from LASSO model
res_lasso = y_test.iloc[:,0] - y_prediction
res_lasso = res_lasso.values

residual_normality_visualizations(y_prediction,res_lasso)

# %% [markdown]
# ### Ridge Regression

# %%
# Creating X and y
formula = ols_formula(clean_df, 'TOTAL_MEDICARE_PAYMENT_AMT')
y, X = patsy.dmatrices(formula, data=clean_df, return_type="dataframe")

# Setting up test and train split
X, X_test, y, y_test = train_test_split(X, y, test_size=.4, random_state=10)

# Scaling X and X_test for ridge
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X.values)
X_test_scaled = scaler.transform(X_test.values)

# Running Model and and finding most optimal alpha
alphavec = 10**np.linspace(-2,2,25)

lm_reg = RidgeCV(alphas = alphavec, cv=5)
lm_reg.fit(X_train_scaled, y)
# Out:
# RidgeCV(alphas=array([1.00000e-02, 1.46780e-02, 2.15443e-02, 3.16228e-02, 4.64159e-02,
#        6.81292e-02, 1.00000e-01, 1.46780e-01, 2.15443e-01, 3.16228e-01,
#        4.64159e-01, 6.81292e-01, 1.00000e+00, 1.46780e+00, 2.15443e+00,
#        3.16228e+00, 4.64159e+00, 6.81292e+00, 1.00000e+01, 1.46780e+01,
#        2.15443e+01, 3.16228e+01, 4.64159e+01, 6.81292e+01, 1.00000e+02]),
#     cv=5, fit_intercept=True, gcv_mode=None, normalize=False, scoring=None,
#     store_cv_values=False)

# %%
# The best alpha for the ridge model
lm_reg.alpha_
# Out:
# 3.1622776601683795

# %%
# Make predictions on the test set using the new model
y_prediction = lm_reg.predict(X_test_scaled)

# %%
# r2 on test set
r2_score(y_test, y_prediction)
# Out:
# 0.9199274982681084

# %%
# Mean absolute error (MAE)
np.abs(np.e**(y_prediction)- np.e**(y_test)).mean()
# Out:
# TOTAL_MEDICARE_PAYMENT_AMT    26682.811644
# dtype: float64

# %%
# Root Mean Squared Error (RMSE)
np.sqrt(mean_squared_error(np.e**(y_test), np.e**(y_prediction)))
# Out:
# 116389.51463022298

# %%
# Finding residuals of test data vs prediction from Ridge model
res_ridge = y_test.iloc[:,0].values - [x[0] for x in y_prediction]

residual_normality_visualizations(y_prediction,res_ridge)

# %% [markdown]
# ## Best Model Results
# - **Ridge** did insignificantly better than LASSO on out of sample data
# - **0.919927498** vs. 0.919927163

# %%
# Pickling the best model - Ridge Regression and column names

redo_pickle = False

if redo_pickle == True:
    with open('lm_reg.pickle','wb') as f:
        pickle.dump(lm_reg, f)
    with open('column_names.pickle','wb') as c:
        pickle.dump(X.columns, c)
